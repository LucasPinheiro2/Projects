# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy

# %%
df = pd.read_csv("jplus_sspp.txt",sep=' ')
df
# Out:
#                SPSPEC          RA        DEC  TEFF   LOGG    FEH SPECTYPE  \
# 0     0355-51788-0064  260.550224  56.905830  6076  4.213 -1.151       F5
# 1     0357-51813-0372  259.215038  56.600472  8273  3.306 -2.597       A0
# 2     0357-51813-0411  259.740867  56.364036  8982  4.501 -3.510       WD
# 3     0357-51813-0550  261.044995  56.208497  5646  3.337 -2.025       F5
# 4     0358-51818-0039  265.047230  56.213000  8774  3.411 -2.000       A0
# 5     0358-51818-0156  263.848600  56.275507  8041  3.493 -2.191       A0
# 6     0358-51818-0277  262.237362  56.366903  5721  4.479 -1.217       G2
# 7     0358-51818-0518  263.326016  57.008204  6048  4.040 -1.784       F5
# 8     0358-51818-0522  264.092504  57.595325  6404  4.225 -1.665       F5
# 9     0358-51818-0538  263.792936  57.273152  7849  3.551 -2.394       A0
# 10    0358-51818-0555  264.506016  56.763370  7520  4.089 -1.113       A0
# 11    0358-51818-0584  264.708855  57.026715  7779  4.026 -1.211       A0
# ...

# %%
plt.scatter(df.TEFF,df.uJAVA-df.J0378)

# %%
plt.scatter(df.TEFF,df.uJAVA-df.J0395)

# %%
plt.scatter(df.TEFF,df.uJAVA-df.J0410)

# %%
plt.scatter(df.TEFF,df.uJAVA-df.J0430)

# %%
plt.scatter(df.TEFF,df.uJAVA-df.gSDSS)

# %%
plt.scatter(df.TEFF,df.uJAVA-df.J0515)

# %%
plt.scatter(df.TEFF,df.uJAVA-df.rSDSS)

# %%
plt.scatter(df.TEFF,df.uJAVA-df.J0660)

# %%
plt.scatter(df.TEFF,df.uJAVA-df.iSDSS)

# %%
plt.scatter(df.TEFF,df.uJAVA-df.J0861)

# %%
plt.scatter(df.TEFF,df.uJAVA-df.zSDSS)

# %%
plt.scatter(df.TEFF,df.J0378-df.J0395)

# %%
plt.scatter(df.TEFF,df.J0378-df.J0410)

# %%
plt.scatter(df.TEFF,df.J0378-df.J0430)

# %%
plt.scatter(df.TEFF,df.J0378-df.gSDSS)

# %%
plt.scatter(df.TEFF,df.J0378-df.J0515)

# %%
plt.scatter(df.TEFF,df.J0378-df.rSDSS)

# %%
plt.scatter(df.TEFF,df.J0378-df.J0660)

# %%
plt.scatter(df.TEFF,df.J0378-df.iSDSS)

# %%
plt.scatter(df.TEFF,df.J0378-df.J0861)

# %%
plt.scatter(df.TEFF,df.J0378-df.zSDSS)

# %%
plt.scatter(df.TEFF,df.J0395-df.J0410)

# %%
plt.scatter(df.TEFF,df.J0395-df.J0430)

# %%
plt.scatter(df.TEFF,df.J0395-df.gSDSS)

# %%
plt.scatter(df.TEFF,df.J0395-df.J0515)

# %%
plt.scatter(df.TEFF,df.J0395-df.rSDSS)

# %%
plt.scatter(df.TEFF,df.J0395-df.J0660)

# %%
plt.scatter(df.TEFF,df.J0395-df.iSDSS)

# %%
plt.scatter(df.TEFF,df.J0395-df.J0861)

# %%
plt.scatter(df.TEFF,df.J0395-df.zSDSS)

# %%
plt.scatter(df.TEFF,df.J0410-df.J0430)

# %%
plt.scatter(df.TEFF,df.J0410-df.gSDSS)

# %%
plt.scatter(df.TEFF,df.J0410-df.J0515)

# %%
plt.scatter(df.TEFF,df.J0410-df.rSDSS)

# %%
plt.scatter(df.TEFF,df.J0410-df.J0660)

# %%
plt.scatter(df.TEFF,df.J0410-df.iSDSS)

# %%
plt.scatter(df.TEFF,df.J0410-df.J0861)

# %%
plt.scatter(df.TEFF,df.J0410-df.zSDSS)

# %%
plt.scatter(df.TEFF,df.J0430-df.gSDSS)

# %%
plt.scatter(df.TEFF,df.J0430-df.J0515)

# %%
plt.scatter(df.TEFF,df.J0430-df.rSDSS)

# %%
plt.scatter(df.TEFF,df.J0430-df.J0660)

# %%
plt.scatter(df.TEFF,df.J0430-df.iSDSS)

# %%
plt.scatter(df.TEFF,df.J0430-df.J0861)

# %%
plt.scatter(df.TEFF,df.J0430-df.zSDSS)

# %%
plt.scatter(df.TEFF,df.gSDSS-df.J0515)

# %%
plt.scatter(df.TEFF,df.gSDSS-df.rSDSS)

# %%
plt.scatter(df.TEFF,df.gSDSS-df.J0660)

# %%
plt.scatter(df.TEFF,df.gSDSS-df.iSDSS)

# %%
plt.scatter(df.TEFF,df.gSDSS-df.J0861)

# %%
plt.scatter(df.TEFF,df.gSDSS-df.zSDSS)

# %%
plt.scatter(df.TEFF,df.J0515-df.rSDSS)

# %%
plt.scatter(df.TEFF,df.J0515-df.J0660)

# %%
plt.scatter(df.TEFF,df.J0515-df.iSDSS)

# %%
plt.scatter(df.TEFF,df.J0515-df.J0861)

# %%
plt.scatter(df.TEFF,df.J0515-df.zSDSS)

# %%
plt.scatter(df.TEFF,df.rSDSS-df.J0660)

# %%
plt.scatter(df.TEFF,df.rSDSS-df.iSDSS)

# %%
plt.scatter(df.TEFF,df.rSDSS-df.J0861)

# %%
plt.scatter(df.TEFF,df.rSDSS-df.zSDSS)

# %%
plt.scatter(df.TEFF,df.J0660-df.iSDSS)

# %%
plt.scatter(df.TEFF,df.J0660-df.J0861)

# %%
plt.scatter(df.TEFF,df.J0660-df.zSDSS)

# %%
plt.scatter(df.TEFF,df.iSDSS-df.J0861)

# %%
plt.scatter(df.TEFF,df.iSDSS-df.zSDSS)

# %%
plt.scatter(df.TEFF,df.J0861-df.zSDSS)

# %%
plt.scatter(df.LOGG,df.uJAVA-df.J0378)

# %%
plt.scatter(df.LOGG,df.uJAVA-df.J0395)

# %%
plt.scatter(df.LOGG,df.uJAVA-df.J0410)

# %%
plt.scatter(df.LOGG,df.uJAVA-df.J0430)

# %%
plt.scatter(df.LOGG,df.uJAVA-df.gSDSS)

# %%
plt.scatter(df.LOGG,df.uJAVA-df.J0515)

# %%
plt.scatter(df.LOGG,df.uJAVA-df.rSDSS)

# %%
plt.scatter(df.LOGG,df.uJAVA-df.J0660)

# %%
plt.scatter(df.LOGG,df.uJAVA-df.iSDSS)

# %%
plt.scatter(df.LOGG,df.uJAVA-df.J0861)

# %%
plt.scatter(df.LOGG,df.uJAVA-df.zSDSS)

# %%
plt.scatter(df.LOGG,df.J0378-df.J0395)

# %%
plt.scatter(df.LOGG,df.J0378-df.J0410)

# %%
plt.scatter(df.LOGG,df.J0378-df.J0430)

# %%
plt.scatter(df.LOGG,df.J0378-df.gSDSS)

# %%
plt.scatter(df.LOGG,df.J0378-df.J0515)

# %%
plt.scatter(df.LOGG,df.J0378-df.rSDSS)

# %%
plt.scatter(df.LOGG,df.J0378-df.J0660)

# %%
plt.scatter(df.LOGG,df.J0378-df.iSDSS)

# %%
plt.scatter(df.LOGG,df.J0378-df.J0861)

# %%
plt.scatter(df.LOGG,df.J0378-df.zSDSS)

# %%
plt.scatter(df.LOGG,df.J0395-df.J0410)

# %%
plt.scatter(df.LOGG,df.J0395-df.J0430)

# %%
plt.scatter(df.LOGG,df.J0395-df.gSDSS)

# %%
plt.scatter(df.LOGG,df.J0395-df.J0515)

# %%
plt.scatter(df.LOGG,df.J0395-df.rSDSS)

# %%
plt.scatter(df.LOGG,df.J0395-df.J0660)

# %%
plt.scatter(df.LOGG,df.J0395-df.iSDSS)

# %%
plt.scatter(df.LOGG,df.J0395-df.J0861)

# %%
plt.scatter(df.LOGG,df.J0395-df.zSDSS)

# %%
plt.scatter(df.LOGG,df.J0410-df.J0430)

# %%
plt.scatter(df.LOGG,df.J0410-df.gSDSS)

# %%
plt.scatter(df.LOGG,df.J0410-df.J0515)

# %%
plt.scatter(df.LOGG,df.J0410-df.rSDSS)

# %%
plt.scatter(df.LOGG,df.J0410-df.J0660)

# %%
plt.scatter(df.LOGG,df.J0410-df.iSDSS)

# %%
plt.scatter(df.LOGG,df.J0410-df.J0861)

# %%
plt.scatter(df.LOGG,df.J0410-df.zSDSS)

# %%
plt.scatter(df.LOGG,df.J0430-df.gSDSS)

# %%
plt.scatter(df.LOGG,df.J0430-df.J0515)

# %%
plt.scatter(df.LOGG,df.J0430-df.rSDSS)

# %%
plt.scatter(df.LOGG,df.J0430-df.J0660)

# %%
plt.scatter(df.LOGG,df.J0430-df.iSDSS)

# %%
plt.scatter(df.LOGG,df.J0430-df.J0861)

# %%
plt.scatter(df.LOGG,df.J0430-df.zSDSS)

# %%
plt.scatter(df.LOGG,df.gSDSS-df.J0515)

# %%
plt.scatter(df.LOGG,df.gSDSS-df.rSDSS)

# %%
plt.scatter(df.LOGG,df.gSDSS-df.J0660)

# %%
plt.scatter(df.LOGG,df.gSDSS-df.iSDSS)

# %%
plt.scatter(df.LOGG,df.gSDSS-df.J0861)

# %%
plt.scatter(df.LOGG,df.gSDSS-df.zSDSS)

# %%
plt.scatter(df.LOGG,df.J0515-df.rSDSS)

# %%
plt.scatter(df.LOGG,df.J0515-df.J0660)

# %%
plt.scatter(df.LOGG,df.J0515-df.iSDSS)

# %%
plt.scatter(df.LOGG,df.J0515-df.J0861)

# %%
plt.scatter(df.LOGG,df.J0515-df.zSDSS)

# %%
plt.scatter(df.LOGG,df.rSDSS-df.J0660)

# %%
plt.scatter(df.LOGG,df.rSDSS-df.iSDSS)

# %%
plt.scatter(df.LOGG,df.rSDSS-df.J0861)

# %%
plt.scatter(df.LOGG,df.rSDSS-df.zSDSS)

# %%
plt.scatter(df.LOGG,df.J0660-df.iSDSS)

# %%
plt.scatter(df.LOGG,df.J0660-df.J0861)

# %%
plt.scatter(df.LOGG,df.J0660-df.zSDSS)

# %%
plt.scatter(df.LOGG,df.iSDSS-df.J0861)

# %%
plt.scatter(df.LOGG,df.iSDSS-df.zSDSS)

# %%
plt.scatter(df.LOGG,df.J0861-df.zSDSS)
