# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
from numpy.polynomial.polynomial import polyfit

# %%
df0 = pd.read_csv("jplus_sspp.txt",sep=' ')
df0
# Out:
#                SPSPEC          RA        DEC  TEFF   LOGG    FEH SPECTYPE  \
# 0     0355-51788-0064  260.550224  56.905830  6076  4.213 -1.151       F5
# 1     0357-51813-0372  259.215038  56.600472  8273  3.306 -2.597       A0
# 2     0357-51813-0411  259.740867  56.364036  8982  4.501 -3.510       WD
# 3     0357-51813-0550  261.044995  56.208497  5646  3.337 -2.025       F5
# 4     0358-51818-0039  265.047230  56.213000  8774  3.411 -2.000       A0
# 5     0358-51818-0156  263.848600  56.275507  8041  3.493 -2.191       A0
# 6     0358-51818-0277  262.237362  56.366903  5721  4.479 -1.217       G2
# 7     0358-51818-0518  263.326016  57.008204  6048  4.040 -1.784       F5
# 8     0358-51818-0522  264.092504  57.595325  6404  4.225 -1.665       F5
# 9     0358-51818-0538  263.792936  57.273152  7849  3.551 -2.394       A0
# 10    0358-51818-0555  264.506016  56.763370  7520  4.089 -1.113       A0
# 11    0358-51818-0584  264.708855  57.026715  7779  4.026 -1.211       A0
# ...

# %%
df = df0[df0.TEFF>7500]
df
# Out:
#                SPSPEC          RA        DEC  TEFF   LOGG    FEH SPECTYPE  \
# 1     0357-51813-0372  259.215038  56.600472  8273  3.306 -2.597       A0
# 2     0357-51813-0411  259.740867  56.364036  8982  4.501 -3.510       WD
# 4     0358-51818-0039  265.047230  56.213000  8774  3.411 -2.000       A0
# 5     0358-51818-0156  263.848600  56.275507  8041  3.493 -2.191       A0
# 9     0358-51818-0538  263.792936  57.273152  7849  3.551 -2.394       A0
# 10    0358-51818-0555  264.506016  56.763370  7520  4.089 -1.113       A0
# 11    0358-51818-0584  264.708855  57.026715  7779  4.026 -1.211       A0
# 12    0367-51997-0605  261.364546  56.563424  7969  4.390 -1.337       A0
# 15    0431-51877-0414  113.938322  38.840945  8222  4.294 -1.154       A0
# 16    0432-51884-0187  115.168512  39.870432  7658  3.110 -1.511       A0
# 17    0432-51884-0258  114.371882  39.422731  7915  4.473 -1.259       A0
# 20    0432-51884-0524  116.018507  41.319761  7676  3.950 -1.037       A0
# ...

# %%
plt.scatter(df.TEFF,df.J0395-df.iSDSS)

b,m = polyfit (df.TEFF,df.J0395-df.iSDSS,1)
np.corrcoef(df.TEFF,df.J0395-df.iSDSS)[0,1]
print("y=",b,"+",m,"*x")
plt.plot(df.TEFF,b+m*df.TEFF)
a=np.corrcoef(df.TEFF,df.J0395-df.iSDSS)[0,1]
print(a**2)
# Out:
# y= 3.5674388587058017 + -0.0004242410932151081 *x
# 0.541667542089854

# %%
plt.scatter(df.TEFF,df.J0395-df.J0861)

b,m = polyfit (df.TEFF,df.J0395-df.J0861,1)
np.corrcoef(df.TEFF,df.J0395-df.J0861)[0,1]
print("y=",b,"+",m,"*x")
plt.plot(df.TEFF,b+m*df.TEFF)
a=np.corrcoef(df.TEFF,df.J0395-df.J0861)[0,1]
print(a**2)
# Out:
# y= 3.913494769620475 + -0.00047634265668748904 *x
# 0.5176373555912497

# %%
plt.scatter(df.TEFF,df.J0395-df.zSDSS)

b,m = polyfit (df.TEFF,df.J0395-df.zSDSS,1)
np.corrcoef(df.TEFF,df.J0395-df.zSDSS)[0,1]
print("y=",b,"+",m,"*x")
plt.plot(df.TEFF,b+m*df.TEFF)
a=np.corrcoef(df.TEFF,df.J0395-df.zSDSS)[0,1]
print(a**2)
# Out:
# y= 4.050628369701464 + -0.0004910799726733369 *x
# 0.5175831691051586

# %%
plt.scatter(df.TEFF,df.J0410-df.J0430)

b,m = polyfit (df.TEFF,df.J0410-df.J0430,1)
np.corrcoef(df.TEFF,df.J0410-df.J0430)[0,1]
print("y=",b,"+",m,"*x")
plt.plot(df.TEFF,b+m*df.TEFF)
a=np.corrcoef(df.TEFF,df.J0410-df.J0430)[0,1]
print(a**2)
# Out:
# y= 0.17760182379192552 + -2.315841581842771e-05 *x
# 0.04178015956043111

# %%
plt.scatter(df.TEFF,df.J0410-df.J0515)

b,m = polyfit (df.TEFF,df.J0410-df.J0515,1)
np.corrcoef(df.TEFF,df.J0410-df.J0515)[0,1]
print("y=",b,"+",m,"*x")
plt.plot(df.TEFF,b+m*df.TEFF)
a=np.corrcoef(df.TEFF,df.J0410-df.J0515)[0,1]
print(a**2)
# Out:
# y= 1.1366339162172232 + -0.00013269254913999702 *x
# 0.3631656511410322

# %%
plt.scatter(df.TEFF,df.J0410-df.rSDSS)

b,m = polyfit (df.TEFF,df.J0410-df.rSDSS,1)
np.corrcoef(df.TEFF,df.J0410-df.rSDSS)[0,1]
print("y=",b,"+",m,"*x")
plt.plot(df.TEFF,b+m*df.TEFF)
a=np.corrcoef(df.TEFF,df.J0410-df.rSDSS)[0,1]
print(a**2)
# Out:
# y= 2.071985675942261 + -0.00025604367528008187 *x
# 0.5384518122011067

# %%
plt.scatter(df.TEFF,df.J0410-df.J0660)

b,m = polyfit (df.TEFF,df.J0410-df.J0660,1)
np.corrcoef(df.TEFF,df.J0410-df.J0660)[0,1]
print("y=",b,"+",m,"*x")
plt.plot(df.TEFF,b+m*df.TEFF)
a=np.corrcoef(df.TEFF,df.J0410-df.J0660)[0,1]
print(a**2)
# Out:
# y= 2.5294270318156538 + -0.00032601081463572883 *x
# 0.5651319799445901

# %%
plt.scatter(df.TEFF,df.J0410-df.iSDSS)

b,m = polyfit (df.TEFF,df.J0410-df.iSDSS,1)
np.corrcoef(df.TEFF,df.J0410-df.iSDSS)[0,1]
print("y=",b,"+",m,"*x")
plt.plot(df.TEFF,b+m*df.TEFF)
a=np.corrcoef(df.TEFF,df.J0410-df.iSDSS)[0,1]
print(a**2)
# Out:
# y= 3.0800951947589965 + -0.00039079229087678874 *x
# 0.5916955604028838

# %%
plt.scatter(df.TEFF,df.J0410-df.J0861)

b,m = polyfit (df.TEFF,df.J0410-df.J0861,1)
np.corrcoef(df.TEFF,df.J0410-df.J0861)[0,1]
print("y=",b,"+",m,"*x")
plt.plot(df.TEFF,b+m*df.TEFF)
a=np.corrcoef(df.TEFF,df.J0410-df.J0861)[0,1]
print(a**2)
# Out:
# y= 3.4261511056736698 + -0.0004428938543491696 *x
# 0.5508103773784728

# %%
plt.scatter(df.TEFF,df.J0410-df.zSDSS)

b,m = polyfit (df.TEFF,df.J0410-df.zSDSS,1)
np.corrcoef(df.TEFF,df.J0410-df.zSDSS)[0,1]
print("y=",b,"+",m,"*x")
plt.plot(df.TEFF,b+m*df.TEFF)
a=np.corrcoef(df.TEFF,df.J0410-df.zSDSS)[0,1]
print(a**2)
# Out:
# y= 3.563284705754658 + -0.00045763117033501764 *x
# 0.5261122193934523

# %%
plt.scatter(df.TEFF,df.J0430-df.rSDSS)

b,m = polyfit (df.TEFF,df.J0430-df.rSDSS,1)
np.corrcoef(df.TEFF,df.J0430-df.rSDSS)[0,1]
print("y=",b,"+",m,"*x")
plt.plot(df.TEFF,b+m*df.TEFF)
a=np.corrcoef(df.TEFF,df.J0430-df.rSDSS)[0,1]
print(a**2)
# Out:
# y= 1.8943838521503358 + -0.0002328852594616542 *x
# 0.5429337917669214

# %%
plt.scatter(df.TEFF,df.J0430-df.J0660)

b,m = polyfit (df.TEFF,df.J0430-df.J0660,1)
np.corrcoef(df.TEFF,df.J0430-df.J0660)[0,1]
print("y=",b,"+",m,"*x")
plt.plot(df.TEFF,b+m*df.TEFF)
a=np.corrcoef(df.TEFF,df.J0430-df.J0660)[0,1]
print(a**2)
# Out:
# y= 2.3518252080237274 + -0.000302852398817301 *x
# 0.563513708809772

# %%
plt.scatter(df.TEFF,df.J0430-df.iSDSS)

b,m = polyfit (df.TEFF,df.J0430-df.iSDSS,1)
np.corrcoef(df.TEFF,df.J0430-df.iSDSS)[0,1]
print("y=",b,"+",m,"*x")
plt.plot(df.TEFF,b+m*df.TEFF)
a=np.corrcoef(df.TEFF,df.J0430-df.iSDSS)[0,1]
print(a**2)
# Out:
# y= 2.9024933709670706 + -0.00036763387505836097 *x
# 0.596902109126714

# %%
plt.scatter(df.TEFF,df.J0430-df.J0861)

b,m = polyfit (df.TEFF,df.J0430-df.J0861,1)
np.corrcoef(df.TEFF,df.J0430-df.J0861)[0,1]
print("y=",b,"+",m,"*x")
plt.plot(df.TEFF,b+m*df.TEFF)
a=np.corrcoef(df.TEFF,df.J0430-df.J0861)[0,1]
print(a**2)
# Out:
# y= 3.2485492818817443 + -0.00041973543853074196 *x
# 0.5396694728818114

# %%
plt.scatter(df.TEFF,df.J0430-df.zSDSS)

b,m = polyfit (df.TEFF,df.J0430-df.zSDSS,1)
np.corrcoef(df.TEFF,df.J0430-df.zSDSS)[0,1]
print("y=",b,"+",m,"*x")
plt.plot(df.TEFF,b+m*df.TEFF)
a=np.corrcoef(df.TEFF,df.J0430-df.zSDSS)[0,1]
print(a**2)
# Out:
# y= 3.385682881962731 + -0.0004344727545165897 *x
# 0.516414754029447

# %%
plt.scatter(df.TEFF,df.gSDSS-df.rSDSS)

b,m = polyfit (df.TEFF,df.gSDSS-df.rSDSS,1)
np.corrcoef(df.TEFF,df.gSDSS-df.rSDSS)[0,1]
print("y=",b,"+",m,"*x")
plt.plot(df.TEFF,b+m*df.TEFF)
a=np.corrcoef(df.TEFF,df.gSDSS-df.rSDSS)[0,1]
print(a**2)
# Out:
# y= 1.2826899081594025 + -0.00016263779537522337 *x
# 0.4941334678375188

# %%
plt.scatter(df.TEFF,df.gSDSS-df.J0660)

b,m = polyfit (df.TEFF,df.gSDSS-df.J0660,1)
np.corrcoef(df.TEFF,df.gSDSS-df.J0660)[0,1]
print("y=",b,"+",m,"*x")
plt.plot(df.TEFF,b+m*df.TEFF)
a=np.corrcoef(df.TEFF,df.gSDSS-df.J0660)[0,1]
print(a**2)
# Out:
# y= 1.740131264032795 + -0.0002326049347308702 *x
# 0.5117350504900438

# %%
plt.scatter(df.TEFF,df.gSDSS-df.iSDSS)

b,m = polyfit (df.TEFF,df.gSDSS-df.iSDSS,1)
np.corrcoef(df.TEFF,df.gSDSS-df.iSDSS)[0,1]
print("y=",b,"+",m,"*x")
plt.plot(df.TEFF,b+m*df.TEFF)
a=np.corrcoef(df.TEFF,df.gSDSS-df.iSDSS)[0,1]
print(a**2)
# Out:
# y= 2.2907994269761387 + -0.0002973864109719302 *x
# 0.5544091357829183

# %%
plt.scatter(df.TEFF,df.gSDSS-df.J0861)

b,m = polyfit (df.TEFF,df.gSDSS-df.J0861,1)
np.corrcoef(df.TEFF,df.gSDSS-df.J0861)[0,1]
print("y=",b,"+",m,"*x")
plt.plot(df.TEFF,b+m*df.TEFF)
a=np.corrcoef(df.TEFF,df.gSDSS-df.J0861)[0,1]
print(a**2)
# Out:
# y= 2.636855337890811 + -0.00034948797444431105 *x
# 0.473462712905648

# %%
plt.scatter(df.TEFF,df.gSDSS-df.zSDSS)

b,m = polyfit (df.TEFF,df.gSDSS-df.zSDSS,1)
np.corrcoef(df.TEFF,df.gSDSS-df.zSDSS)[0,1]
print("y=",b,"+",m,"*x")
plt.plot(df.TEFF,b+m*df.TEFF)
a=np.corrcoef(df.TEFF,df.gSDSS-df.zSDSS)[0,1]
print(a**2)
# Out:
# y= 2.7739889379717995 + -0.00036422529043015896 *x
# 0.46778465243288986

# %%
plt.scatter(df.TEFF,df.J0515-df.rSDSS)

b,m = polyfit (df.TEFF,df.J0515-df.rSDSS,1)
np.corrcoef(df.TEFF,df.J0515-df.rSDSS)[0,1]
print("y=",b,"+",m,"*x")
plt.plot(df.TEFF,b+m*df.TEFF)
a=np.corrcoef(df.TEFF,df.J0515-df.rSDSS)[0,1]
print(a**2)
# Out:
# y= 0.9353517597250385 + -0.00012335112614008495 *x
# 0.38660277686422445

# %%
plt.scatter(df.TEFF,df.J0515-df.J0660)

b,m = polyfit (df.TEFF,df.J0515-df.J0660,1)
np.corrcoef(df.TEFF,df.J0515-df.J0660)[0,1]
print("y=",b,"+",m,"*x")
plt.plot(df.TEFF,b+m*df.TEFF)
a=np.corrcoef(df.TEFF,df.J0515-df.J0660)[0,1]
print(a**2)
# Out:
# y= 1.3927931155984312 + -0.0001933182654957319 *x
# 0.3821685673554594

# %%
plt.scatter(df.TEFF,df.J0515-df.iSDSS)

b,m = polyfit (df.TEFF,df.J0515-df.iSDSS,1)
np.corrcoef(df.TEFF,df.J0515-df.iSDSS)[0,1]
print("y=",b,"+",m,"*x")
plt.plot(df.TEFF,b+m*df.TEFF)
a=np.corrcoef(df.TEFF,df.J0515-df.iSDSS)[0,1]
print(a**2)
# Out:
# y= 1.9434612785417735 + -0.00025809974173679175 *x
# 0.5118173156654523

# %%
plt.scatter(df.TEFF,df.J0515-df.J0861)

b,m = polyfit (df.TEFF,df.J0515-df.J0861,1)
np.corrcoef(df.TEFF,df.J0515-df.J0861)[0,1]
print("y=",b,"+",m,"*x")
plt.plot(df.TEFF,b+m*df.TEFF)
a=np.corrcoef(df.TEFF,df.J0515-df.J0861)[0,1]
print(a**2)
# Out:
# y= 2.2895171894564466 + -0.00031020130520917257 *x
# 0.43956693661603097

# %%
plt.scatter(df.TEFF,df.J0515-df.zSDSS)

b,m = polyfit (df.TEFF,df.J0515-df.zSDSS,1)
np.corrcoef(df.TEFF,df.J0515-df.zSDSS)[0,1]
print("y=",b,"+",m,"*x")
plt.plot(df.TEFF,b+m*df.TEFF)
a=np.corrcoef(df.TEFF,df.J0515-df.zSDSS)[0,1]
print(a**2)
# Out:
# y= 2.4266507895374345 + -0.00032493862119502054 *x
# 0.4088048583515272

# %%
plt.scatter(df.TEFF,df.rSDSS-df.iSDSS)

b,m = polyfit (df.TEFF,df.rSDSS-df.iSDSS,1)
np.corrcoef(df.TEFF,df.rSDSS-df.iSDSS)[0,1]
print("y=",b,"+",m,"*x")
plt.plot(df.TEFF,b+m*df.TEFF)
a=np.corrcoef(df.TEFF,df.rSDSS-df.iSDSS)[0,1]
print(a**2)
# Out:
# y= 1.008109518816735 + -0.0001347486155967068 *x
# 0.3538206724073704

# %%
plt.scatter(df.TEFF,df.rSDSS-df.J0861)

b,m = polyfit (df.TEFF,df.rSDSS-df.J0861,1)
np.corrcoef(df.TEFF,df.rSDSS-df.J0861)[0,1]
print("y=",b,"+",m,"*x")
plt.plot(df.TEFF,b+m*df.TEFF)
a=np.corrcoef(df.TEFF,df.rSDSS-df.J0861)[0,1]
print(a**2)
# Out:
# y= 1.3541654297314085 + -0.00018685017906908773 *x
# 0.28947493881861025

# %%
plt.scatter(df.TEFF,df.rSDSS-df.zSDSS)

b,m = polyfit (df.TEFF,df.rSDSS-df.zSDSS,1)
np.corrcoef(df.TEFF,df.rSDSS-df.zSDSS)[0,1]
print("y=",b,"+",m,"*x")
plt.plot(df.TEFF,b+m*df.TEFF)
a=np.corrcoef(df.TEFF,df.rSDSS-df.zSDSS)[0,1]
print(a**2)
# Out:
# y= 1.4912990298123967 + -0.0002015874950549356 *x
# 0.27389273352254073

# %%
plt.scatter(df.TEFF,df.J0660-df.iSDSS)

b,m = polyfit (df.TEFF,df.J0660-df.iSDSS,1)
np.corrcoef(df.TEFF,df.J0660-df.iSDSS)[0,1]
print("y=",b,"+",m,"*x")
plt.plot(df.TEFF,b+m*df.TEFF)
a=np.corrcoef(df.TEFF,df.J0660-df.iSDSS)[0,1]
print(a**2)
# Out:
# y= 0.5506681629433425 + -6.47814762410599e-05 *x
# 0.11923276158189215

# %%
plt.scatter(df.TEFF,df.J0660-df.J0861)

b,m = polyfit (df.TEFF,df.J0660-df.J0861,1)
np.corrcoef(df.TEFF,df.J0660-df.J0861)[0,1]
print("y=",b,"+",m,"*x")
plt.plot(df.TEFF,b+m*df.TEFF)
a=np.corrcoef(df.TEFF,df.J0660-df.J0861)[0,1]
print(a**2)
# Out:
# y= 0.8967240738580158 + -0.00011688303971344079 *x
# 0.16796404600819026

# %%
plt.scatter(df.LOGG,df.J0410-df.J0430)

b,m = polyfit (df.LOGG,df.J0410-df.J0430,1)
np.corrcoef(df.LOGG,df.J0410-df.J0430)[0,1]
print("y=",b,"+",m,"*x")
plt.plot(df.LOGG,b+m*df.LOGG)
a=np.corrcoef(df.LOGG,df.J0410-df.J0430)[0,1]
print(a**2)
# Out:
# y= -0.07687302234818609 + 0.01653341422631537 *x
# 0.026579399490480205

# %%
plt.scatter(df.LOGG,df.J0660-df.iSDSS)

b,m = polyfit (df.LOGG,df.J0660-df.iSDSS,1)
np.corrcoef(df.LOGG,df.J0660-df.iSDSS)[0,1]
print("y=",b,"+",m,"*x")
plt.plot(df.LOGG,b+m*df.LOGG)
a=np.corrcoef(df.LOGG,df.J0660-df.iSDSS)[0,1]
print(a**2)
# Out:
# y= -0.21041314778891043 + 0.05881308967123909 *x
# 0.12266187089272346
